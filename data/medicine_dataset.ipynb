# %%
import pandas as pd

# %%
df = pd.read_csv("medicine_dataset.csv")
# Out:
# /var/folders/gy/4xgmb9991050cgxb1tc_8x_h0000gn/T/ipykernel_75803/2144720450.py:1: DtypeWarning: Columns (42,43,44,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("medicine_dataset.csv")

# %%
df.head()
# Out:
#    id                      name                     substitute0  \
# 0   1  augmentin 625 duo tablet  Penciclav 500 mg/125 mg Tablet
# 1   2       azithral 500 tablet         Zithrocare 500mg Tablet
# 2   3          ascoril ls syrup                 Solvin LS Syrup
# 3   4      allegra 120mg tablet                    Lcfex Tablet
# 4   5            avil 25 tablet              Eralet 25mg Tablet
#
#               substitute1              substitute2            substitute3  \
# 0  Moxikind-CV 625 Tablet  Moxiforce-CV 625 Tablet     Fightox 625 Tablet
# 1         Azax 500 Tablet          Zady 500 Tablet  Cazithro 500mg Tablet
# 2       Ambrodil-LX Syrup        Zerotuss XP Syrup         Capex LS Syrup
# 3     Etofex 120mg Tablet     Nexofex 120mg Tablet    Fexise 120mg Tablet
# 4                     NaN                      NaN                    NaN
#
#                substitute4 sideEffect0       sideEffect1     sideEffect2  ...  \
# ...

# %%
len(df["Action Class"].unique())
# Out:
# 432

# %%
df["Action Class"].count()
# Out:
# np.int64(138036)

# %%
df['Substitutions'] = df.iloc[:, 2:7].apply(lambda row: ','.join(row.dropna().astype(str)), axis=1)

df[['Substitutions']].head()
# Out:
#                                        Substitutions
# 0  Penciclav 500 mg/125 mg Tablet,Moxikind-CV 625...
# 1  Zithrocare 500mg Tablet,Azax 500 Tablet,Zady 5...
# 2  Solvin LS Syrup,Ambrodil-LX Syrup,Zerotuss XP ...
# 3  Lcfex Tablet,Etofex 120mg Tablet,Nexofex 120mg...
# 4                                 Eralet 25mg Tablet

# %%
# df['SideEffects'] = df.iloc[:, 2:7].apply(lambda row: ','.join(row.dropna().astype(str)), axis=1)
# 
# df[['SideEffects']].head()

# %%
df['SideEffects'] = df.iloc[:, 7:48].apply(lambda row: ','.join(row.dropna().astype(str)), axis=1)

df[['SideEffects']].head()
# Out:
#                                          SideEffects
# 0                           Vomiting,Nausea,Diarrhea
# 1            Vomiting,Nausea,Abdominal pain,Diarrhea
# 2  Nausea,Vomiting,Diarrhea,Upset stomach,Stomach...
# 3               Headache,Drowsiness,Dizziness,Nausea
# 4                        Sleepiness,Dryness in mouth

# %%
# new_df = df['name'] + df['Substitutions'] + df['SideEffects'] + df["Action Class"]
new_df = df[['name', 'Substitutions', 'SideEffects', "Habit Forming"]]

new_df.head()
# Out:
#                        name  \
# 0  augmentin 625 duo tablet
# 1       azithral 500 tablet
# 2          ascoril ls syrup
# 3      allegra 120mg tablet
# 4            avil 25 tablet
#
#                                        Substitutions  \
# 0  Penciclav 500 mg/125 mg Tablet,Moxikind-CV 625...
# 1  Zithrocare 500mg Tablet,Azax 500 Tablet,Zady 5...
# 2  Solvin LS Syrup,Ambrodil-LX Syrup,Zerotuss XP ...
# 3  Lcfex Tablet,Etofex 120mg Tablet,Nexofex 120mg...
# 4                                 Eralet 25mg Tablet
#
#                                          SideEffects Habit Forming
# 0                           Vomiting,Nausea,Diarrhea            No
# 1            Vomiting,Nausea,Abdominal pain,Diarrhea            No
# 2  Nausea,Vomiting,Diarrhea,Upset stomach,Stomach...            No
# 3               Headache,Drowsiness,Dizziness,Nausea            No
# 4                        Sleepiness,Dryness in mouth            No

# %%
new_df.to_csv("updated_medicine_dataset.csv")

# %%
new_df["Habit Forming"] = new_df["Habit Forming"].replace("No", False)
new_df["Habit Forming"] = new_df["Habit Forming"].replace("Yes", True)
new_df.head()
# Out:
# /var/folders/gy/4xgmb9991050cgxb1tc_8x_h0000gn/T/ipykernel_75803/1141810385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Habit Forming"] = new_df["Habit Forming"].replace("No", False)
# /var/folders/gy/4xgmb9991050cgxb1tc_8x_h0000gn/T/ipykernel_75803/1141810385.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   new_df["Habit Forming"] = new_df["Habit Forming"].replace("Yes", True)
# /var/folders/gy/4xgmb9991050cgxb1tc_8x_h0000gn/T/ipykernel_75803/1141810385.py:2: SettingWithCopyWarning:
# ...

# %%
new_df.head(100)
# Out:
#                          name  \
# 0    augmentin 625 duo tablet
# 1         azithral 500 tablet
# 2            ascoril ls syrup
# 3        allegra 120mg tablet
# 4              avil 25 tablet
# ..                        ...
# 95  antid 300mcg/ml injection
# 96               alerid syrup
# 97        aldactone 50 tablet
# 98        ampoxin 500 capsule
# 99            azee 250 tablet
#
#                                         Substitutions  \
# 0   Penciclav 500 mg/125 mg Tablet,Moxikind-CV 625...
# 1   Zithrocare 500mg Tablet,Azax 500 Tablet,Zady 5...
# 2   Solvin LS Syrup,Ambrodil-LX Syrup,Zerotuss XP ...
# 3   Lcfex Tablet,Etofex 120mg Tablet,Nexofex 120mg...
# 4                                  Eralet 25mg Tablet
# ..                                                ...
# 95
# 96  Cetrilix 5mg Syrup,Cetmac 5mg/5ml Syrup,Ralcet...
# 97  Spilactone 50mg Tablet,Spirix 50 Tablet,Spirol...
# 98  Baciclox Plus Capsule,Cilclox 250mg/250mg Caps...
# ...
